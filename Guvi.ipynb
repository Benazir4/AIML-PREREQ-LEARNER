# %% [markdown]
# <a href="https://colab.research.google.com/github/Benazir4/AIML-PREREQ-LEARNER/blob/main/Guvi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Benz")
# Out:
# Benz

# %%
print("Benazir")
# Out:
# Benazir
